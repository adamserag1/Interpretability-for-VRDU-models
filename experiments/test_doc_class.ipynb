# %% [markdown]
# #Test
#
# Example of how to clone the repo, change the working dir, and load a util

# %%
# !git clone https://github.com/adamserag1/Interpretability-for-VRDU-models.git
# Out:
# Cloning into 'Interpretability-for-VRDU-models'...
# remote: Enumerating objects: 420, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 420 (delta 126), reused 139 (delta 55), pack-reused 185 (from 1)
# Receiving objects: 100% (420/420), 11.66 MiB | 6.68 MiB/s, done.
# Resolving deltas: 100% (209/209), done.

# %%
# !git pull https://github.com/adamserag1/Interpretability-for-VRDU-models.git
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 8 (delta 6), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (8/8), 1.54 KiB | 787.00 KiB/s, done.
# From https://github.com/adamserag1/Interpretability-for-VRDU-models
#  * branch            HEAD       -> FETCH_HEAD
# Updating 60d130e..8349596
# Fast-forward
#  vrdu_utils/utils.py | 59 +++++++++++++++++++++++++++++++++++++++++------------
#  1 file changed, 46 insertions(+), 13 deletions(-)

# %% [markdown]
# #config

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/Interpretability-for-VRDU-models
# Out:
# /content/Interpretability-for-VRDU-models

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -U datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 18.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %% [markdown]
# #code

# %%
from datasets import load_from_disk
from transformers import LayoutLMv3ForSequenceClassification, AutoProcessor
import sys
import importlib
def reload_modules():
    for module in list(sys.modules.keys()):
        if module.startswith('vrdu_utils') or module.startswith('Classification_Explain'):
            print(f"Reloading module: {module}")
            importlib.reload(sys.modules[module])

reload_modules()

from vrdu_utils.encoders import *
from Classification_Explain.lime import *
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import warnings
from transformers import logging as hf_logging

warnings.filterwarnings(
    "ignore",
    category=FutureWarning,
    module="transformers.modeling_utils",   # the module that emits the msg
)
hf_logging.set_verbosity_error()
# Out:
# Reloading module: vrdu_utils.utils
# Reloading module: vrdu_utils.encoders
# Reloading module: vrdu_utils.module_types
# Reloading module: vrdu_utils
# Reloading module: Classification_Explain.lime
# Reloading module: Classification_Explain

# %%
from vrdu_utils.encoders import *
from Classification_Explain.lime import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/THESIS/rvl_cdip_financial_subset /content

# %%
rvl = load_from_disk('/content/rvl_cdip_financial_subset')
sample = rvl[1400]
sample["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>

# %%
sample_ds = DocSample(
    image   = sample["image"].convert("RGB"),
    words   = sample["words"],
    bboxes  = sample["bboxes"],
    label   = sample["label"]              # classification only
)
print(sample_ds)
# Out:
# DocSample(image=<PIL.Image.Image image mode=RGB size=754x1000 at 0x79DF29C9AC90>, words=['WINSTON', '&', 'STRAWN', '25', 'WEST', 'WACKER', 'DAVE', 'AKRON', 'TRIAL', 'SITE', '18a', 'Pate', 'RARE', 'ceenbo,LINerS', 'eno', 'a7e8', 'sr', 'east', 'Tana', 'menus', '—', '“ARRON,', 'OffO', 'seston', 'Pee', '200', 'PARK', 'AVENUE', '‘204', 'GENEVA', 'ST', 'ZERLAND', 'nasi', 'vohae', 'WY', '108989', 'sacenscua', 'rarer', '5', 'STARET,', 'Nw.', '\\wasievOn,', 'Be', 'S000', '8602', '(WRITERS', 'DIRECT', 'DIAL', '(oso', 'areas', 'FACSIMILE', '‘From:', 'Kevin', 'Natko', '#', 'of', 'Pages:', 'Date:', 'March', '10,', '1999', 'Fax', 'Number:', '(305)', '400-6106', '‘Name:', 'Jim', 'McNasby', 'c/o', 'Brian', 'Otero', 'Firm:', 'Hunton', '&', 'Williams', 'Confirming', 'Number:', 'Additional', 'Comments:', '£S82Lepg0z', 'the', 'information', 'contained', 'in', 'this', 'facsimile', 'message', 'is', 'attorney', 'privileged', 'ond', 'confidential', 'information', 'intended', 'only', 'for', 'the', 'uve', 'of
# ...

# %%
LLMV3 = LayoutLMv3ForSequenceClassification.from_pretrained("adamadam111/layoutlmv3-docclass-finetuned")
LLMV3_PROC = AutoProcessor.from_pretrained("microsoft/layoutlmv3-base", apply_ocr=False)
LLMV3.to(device)

# %% [markdown]
# # One sample

# %%
'''
NON ALIGNED BOXES
'''
# Out:
# <mask>

# %%
LLMV3_encode = make_layoutlmv3_encoder_cls(LLMV3_PROC)

text_exp = LimeTextExplainer(
    LLMV3,
    LLMV3_encode,
    mask_token=LLMV3_PROC.tokenizer.mask_token,
    batch_size=2,
    kernel_width_factor=0.75,
)

# %%
vals_non_align = text_exp.explain(sample_ds, align_boxes = False, num_samples=4000, num_features=30)
# Out:
# Begging EXPLAINER
# Begging EXPLAIN_INSTANCE
# MADE PREDICT
# [LIME] - Text: 100%|██████████| 2000/2000 [01:24<00:00, 23.66it/s]

# %%
weights_dict = dict(vals_non_align.as_list())

print("Explanation score (R²):", vals_non_align.score)
for word, weight in vals_non_align.as_list():
  print(f"{word:10s} -> {weight:+.10f}")
# Out:
# Explanation score (R²): 0.5748454456790921
# STRAWN=1   -> +0.0000074638
# Fax=1      -> -0.0000060094
# GENEVA=1   -> +0.0000046511
# WINSTON=1  -> -0.0000038499
# FACSIMILE=1 -> -0.0000032104
# PARK=1     -> +0.0000027513
# AVENUE=1   -> +0.0000024863
# ceenbo,LINerS=1 -> +0.0000023133
# AKRON=1    -> +0.0000018929
# ‘Name:=1   -> -0.0000018132
# DIRECT=1   -> -0.0000016453
# 200=1      -> +0.0000013670
# (WRITERS=1 -> +0.0000013024
# \wasievOn,=1 -> +0.0000013019
# £S82Lepg0z=1 -> +0.0000011497
# &=1        -> +0.0000011478
# ST=1       -> +0.0000010786
# sacenscua=1 -> +0.0000010330
# ZERLAND=1  -> +0.0000010049
# DIAL=1     -> -0.0000009878
# a7e8=1     -> +0.0000009801
# “ARRON,=1  -> +0.0000009606
# areas=1    -> -0.0000009413
# 400-6106=1 -> +0.0000008824
# 108989=1   -> +0.0000008682
# Pages:=1   -> -0.0000008189
# ‘204=1     -> +0.0000008159
# 8602=1     -> +0.0000008098
# east=1     -> +0.0000007329
# Nw.=1      -> +0.0000007072

# %%
enc = LLMV3_encode([sample_ds], device)          # original sample
token_ids = enc["input_ids"][0].tolist()

print("model tokens:", LLMV3_PROC.tokenizer.convert_ids_to_tokens(token_ids[:50]))
print("LIME features:", sample_ds.words[:20])
# Out:
# model tokens: ['<s>', 'ĠWIN', 'STON', 'Ġ&', 'ĠST', 'RAW', 'N', 'Ġ25', 'ĠW', 'EST', 'ĠW', 'ACK', 'ER', 'ĠDA', 'VE', 'ĠAK', 'RON', 'ĠTRI', 'AL', 'ĠS', 'ITE', 'Ġ18', 'a', 'ĠP', 'ate', 'ĠR', 'ARE', 'Ġce', 'en', 'bo', ',', 'LIN', 'er', 'S', 'Ġen', 'o', 'Ġa', '7', 'e', '8', 'Ġsr', 'Ġeast', 'ĠT', 'ana', 'Ġmenus', 'ĠâĢĶ', 'ĠâĢ', 'ľ', 'ARR', 'ON']
# LIME features: ['WINSTON', '&', 'STRAWN', '25', 'WEST', 'WACKER', 'DAVE', 'AKRON', 'TRIAL', 'SITE', '18a', 'Pate', 'RARE', 'ceenbo,LINerS', 'eno', 'a7e8', 'sr', 'east', 'Tana', 'menus']

# %%
'''
ALIGNING BOXES
'''

import re
def clean_words(words, boxes):
  c = 0
  for i, w in enumerate(words):
    if not re.match(r'^[a-zA-Z0-9\s.,:-]+$', w):
      words.remove(w)
      boxes.pop(i)
      c += 1
  print(f'Removed {c} words')
  return words, boxes

# Apply before encoding or LIME
sample_ds.words, sample_ds.bboxes = clean_words(sample_ds.words, sample_ds.bboxes)
# Out:
# Removed 18 words

# %%
vals_aligned_bboxes = text_exp.explain(sample_ds, align_boxes = True, num_samples=4000, num_features=30)
# Out:
# Begging EXPLAINER
# Begging EXPLAIN_INSTANCE
# MADE PREDICT
# [LIME] - Text: 100%|██████████| 2000/2000 [01:24<00:00, 23.65it/s]

# %%
weights_dict_al = dict(vals_aligned_bboxes.as_list())

print("Explanation score (R²):", vals_aligned_bboxes.score)
for word, weight in vals_aligned_bboxes.as_list():
  print(f"{word:10s} -> {weight:+.10f}")
# Out:
# Explanation score (R²): 0.5562234773990691
# FACSIMILE=1 -> -0.0000040826
# STRAWN=1   -> +0.0000033678
# Comments:=1 -> +0.0000023802
# message=1  -> -0.0000023553
# WINSTON=1  -> -0.0000021684
# GENEVA=1   -> +0.0000021644
# Fax=1      -> -0.0000016545
# PARK=1     -> +0.0000016468
# AVENUE=1   -> +0.0000012535
# areas=1    -> -0.0000011451
# ceenbo,LINerS=1 -> +0.0000010838
# facsimile=1 -> -0.0000010221
# SITE=1     -> -0.0000010132
# confidential=1 -> +0.0000010088
# Pages:=1   -> +0.0000009990
# 108989=1   -> +0.0000009949
# privileged=1 -> +0.0000009668
# attorney=1 -> +0.0000008171
# 400-6106=1 -> +0.0000007918
# Number:=1  -> +0.0000007547
# east=1     -> +0.0000007505
# the=1      -> -0.0000007361
# 200=1      -> +0.0000007303
# a7e8=1     -> +0.0000007257
# “ARRON,=1  -> +0.0000007172
# AKRON=1    -> -0.0000007130
# only=1     -> -0.0000006917
# 1999=1     -> +0.0000006412
# TRIAL=1    -> -0.0000006406
# Nw.=1      -> +0.0000006300

# %%
from vrdu_utils.utils import draw_lime_token_heatmap
weights = {}
for token, w in vals_aligned_bboxes.as_list():
    clean = re.sub(r"=\d+$", "", token)     # drop '=number' suffix
    weights[clean] = weights.get(clean, 0.0) + w

draw_lime_token_heatmap(image = sample_ds.image, words = sample_ds.words, boxes = sample_ds.bboxes, weights = weights, alpha = 0.25)
# Out:
# <PIL.Image.Image image mode=RGBA size=754x1000>
